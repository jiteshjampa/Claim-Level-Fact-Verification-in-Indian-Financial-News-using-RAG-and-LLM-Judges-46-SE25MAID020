# %%
# !python load_dataset.py
# Out:
# [load_dataset] Downloading kdave/Indian_Financial_News from HuggingFace ...
# ...
# README.md: 4.51kB [00:00, 5.86MB/s]
# training_data_26000.csv: 100% 115M/115M [00:06<00:00, 17.6MB/s]
# Generating train split: 100% 26961/26961 [00:01<00:00, 13606.43 examples/s]
# [load_dataset] Raw dataset size: 26961 articles
#
# [load_dataset] Dataset Columns:
# ['URL', 'Content', 'Summary', 'Sentiment']
#
# [load_dataset] First Row Sample:
# ...

# %%
# !python main.py --query "What did RBI do with interest rates?"
# Out:
# [ERROR] GROQ_API_KEY not set.
#   Get a free key at https://console.groq.com
#   Then: export GROQ_API_KEY='gsk_...'

# %%
# %env GROQ_API_KEY="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"
# Out:
# env: GROQ_API_KEY="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"

# %%
# !python main.py --query "What did RBI do with interest rates?"
# Out:
# ...
#   FINANCIAL RAG + HALLUCINATION DETECTION PIPELINE
# ...
#   Query       : What did RBI do with interest rates?
#   Top-K       : 3  |  Chunk size: 250w  |  Prompt: strict
# ...
#
# [1/5] Loading dataset ...
# [load_dataset] Loaded 26961 articles from data/financial_news.json
#       26961 articles loaded.
#
# [2/5] Building/loading FAISS index ...
# [retriever] Loading cached index (data/faiss_index.pkl.cs250.ov40) ...
# [retriever] Loaded 89294 chunks.
#       89294 chunks indexed.
#
# [3/5] Retrieving top-3 chunks ...
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 1014.54it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#       Avg retrieval score: 0.6626
# ...

# %%
import os
os.environ["GROQ_API_KEY"] = "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"

# %%
# !pip install faiss-cpu

# %%
# !pip install groq

# %% [markdown]
# The previous error indicated that the model `llama3-8b-8192` is decommissioned. You need to update the model name used in the `generator.py` file.
#
# **Please open the `generator.py` file and change the model name `llama3-8b-8192` to a currently supported model, such as `llama3-8b-8k`.** You can find supported models in the Groq console documentation. After making this change, re-run cell `8w-E6pmoc5xW`.

# %%
# !python main.py --query "What did RBI do with interest rates?"
# Out:
# ...
#   FINANCIAL RAG + HALLUCINATION DETECTION PIPELINE
# ...
#   Query       : What did RBI do with interest rates?
#   Top-K       : 3  |  Chunk size: 250w  |  Prompt: strict
# ...
#
# [1/5] Loading dataset ...
# [load_dataset] Loaded 26961 articles from data/financial_news.json
#       26961 articles loaded.
#
# [2/5] Building/loading FAISS index ...
# [retriever] Loading cached index (data/faiss_index.pkl.cs250.ov40) ...
# [retriever] Loaded 89294 chunks.
#       89294 chunks indexed.
#
# [3/5] Retrieving top-3 chunks ...
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 2021.64it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#       Avg retrieval score: 0.6626
# ...

# %%
# !python main.py --evaluate
# Out:
# [evaluate] Loading dataset ...
# [load_dataset] Loaded 26961 articles from data/financial_news.json
#
# [evaluate] Building default index (chunk=250, overlap=40) ...
# [retriever] Loading cached index (data/faiss_index.pkl.cs250.ov40) ...
# [retriever] Loaded 89294 chunks.
# [evaluate] Index built: 89294 chunks
#
# [evaluate] Running main evaluation on 30 questions ...
#   [01/30] What action did the RBI take regarding the repo rate?
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 2289.52it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   [02/30] How did the RBI respond to inflation concerns?
# ...

# %%
# !python main.py --compare_papers
# Out:
# ...
#   COMPARISON WITH REFERENCE PAPERS
# ...
# System                                      Domain                                              Precision    Recall    F1      Halluc Detection
# ------------------------------------------  --------------------------------------------------  -----------  --------  ------  ------------------
# ★ r System (LLM-as-Judge + SelfCheckGPT)    Indian Financial News (26k articles)                0.23         0.20      0.21    0.23
#   lfCheckGPT (arXiv:2303.08896)             Wikipedia biography generation (GPT-3)              0.73         0.69      0.71    0.68
#   lf-RAG (arXiv:2310.11511)                 Open-domain QA (PopQA, TriviaQA, PubHealth, A...    0.82         0.74      0.78    0.79
#   P4RAG (arXiv:2408.15533)                  Document QA (various benchmarks)                    0.76         0.72      0.74    0.74
#
# ...
#   KEY DIFFERENCES FROM REFERENCE PAPERS
# ...
#
#   vs SelfCheckGPT:
# ...

# %%
# !python plot_results.py
# Out:
# [plot] Loading results ...
# [plot] Generating figures ...
# [plot] Saved results/fig1_hallucination_distribution.png
# [plot] Saved results/fig2_chunk_ablation.png
# [plot] Saved results/fig3_selfcheck_scatter.png
# [plot] Saved results/fig4_paper_comparison.png
# [plot] Saved results/fig5_topk_ablation.png
# [plot] Saved results/fig6_prompt_ablation.png
#
# [plot] All figures saved to results/
#   fig1_hallucination_distribution.png
#   fig2_chunk_ablation.png
#   fig3_selfcheck_scatter.png
#   fig4_paper_comparison.png
#   fig5_topk_ablation.png
#   fig6_prompt_ablation.png

# %%
# !python build_report.py
# Out:
# Traceback (most recent call last):
#   File "/content/build_report.py", line 8, in <module>
#     from reportlab.lib.pagesizes import A4
# ModuleNotFoundError: No module named 'reportlab'

# %%
pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.0 MB/s eta 0:00:00
# ...

# %%
# !python build_report.py
# Out:
# [build_report] Saved: report.pdf
